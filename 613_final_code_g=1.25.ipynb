# %%
import numpy as np
import pandas as pd 
from keras.preprocessing.image import ImageDataGenerator, load_img
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from random import shuffle
import random
import os

# %%
path = 'C:\\Users\\DEEP\\COVID-19-X-Ray-Classification-master\\'

IMAGE_WIDTH = 200
IMAGE_HEIGHT = 200

IMAGE_SIZE = (IMAGE_WIDTH, IMAGE_HEIGHT)
IMAGE_CHANNELS = 3

# %%
directories = ['Training_data_gval']
categories = []
    
files = os.listdir(path + directories[0])

for img in files:

    fileName = img.split('.')[0]
    
    if 'Normal' in fileName: categories.append(0)
    elif 'COVID' in fileName: categories.append(1)
    else: categories.append(2)


df = pd.DataFrame({
    'filename': files,
    'category': categories
})

# %%
df
# Out:
#                    filename  category
# 0               COVID-1.png         1
# 1              COVID-10.png         1
# 2             COVID-100.png         1
# 3             COVID-101.png         1
# 4             COVID-102.png         1
# ..                      ...       ...
# 895  Viral Pneumonia-95.png         2
# 896  Viral Pneumonia-96.png         2
# 897  Viral Pneumonia-97.png         2
# 898  Viral Pneumonia-98.png         2
# 899  Viral Pneumonia-99.png         2
#
# [900 rows x 2 columns]

# %%
'''
0 Represents Normal 
1 Represents COVID-19
2 Represents Viral Pneumonia 
'''
df["category"] = df["category"].astype("category")
df['category'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
sample = random.choice(os.listdir(path + directories[0]))
image = load_img(path + '\\Training_data_gval\\' + sample)

print(sample)
plt.imshow(image)
# Out:
# Viral Pneumonia-15.png

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization

model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, IMAGE_CHANNELS)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.35))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.35))

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.15))

model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.05))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Dense(3, activation='softmax', name='predictions')) 

model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 198, 198, 32)      896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 198, 198, 32)      128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 99, 99, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 99, 99, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 97, 97, 64)        18496
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 97, 97, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 48, 48, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 48, 48, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 46, 46, 128)       73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 46, 46, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 23, 23, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 23, 23, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 21, 21, 64)        73792
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 21, 21, 64)        256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 32)          18464
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 8, 8, 32)          128
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 32)          0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 4, 4, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 512)               262656
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# predictions (Dense)          (None, 3)                 1539
# =================================================================
# Total params: 453,027
# Trainable params: 451,363
# Non-trainable params: 1,664
# _________________________________________________________________

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
earlystop = EarlyStopping(patience=10)

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor = 'val_accuracy', 
                                            patience = 2, 
                                            verbose = 1, 
                                            factor = 0.5, 
                                            min_lr = 0.00001)

callbacks = [earlystop, learning_rate_reduction]

# %%
df["category"] = df["category"].replace({0: 'Normal', 1: 'COVID', 2: 'Viral Pneumonia'})

# %%
df['category'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
df = df.sample(frac=1).reset_index(drop=True)
df
# Out:
#                     filename         category
# 0    Viral Pneumonia-278.png  Viral Pneumonia
# 1    Viral Pneumonia-279.png  Viral Pneumonia
# 2               COVID-49.png            COVID
# 3               COVID-68.png            COVID
# 4             Normal-282.png           Normal
# ..                       ...              ...
# 895            COVID-266.png            COVID
# 896           Normal-194.png           Normal
# 897           Normal-291.png           Normal
# 898           Normal-261.png           Normal
# 899            Normal-20.png           Normal
#
# [900 rows x 2 columns]

# %%
train_df, validate_df = train_test_split(df, test_size=0.20, random_state=42)
train_df = train_df.reset_index(drop=True)
validate_df = validate_df.reset_index(drop=True)

# %%
train_df['category'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
validate_df['category'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
total_train = train_df.shape[0]
total_validate = validate_df.shape[0]
batch_size = 5

# %%
train_datagen = ImageDataGenerator (
    
    #rotation_range = 15,
    rescale = 1./255,
    
   # shear_range = 0.1,
    # zoom_range = 0.2,
    
    #horizontal_flip = True,
    #width_shift_range = 0.1,
    #height_shift_range = 0.1
)

train_generator = train_datagen.flow_from_dataframe (
    
    train_df, 
    path + '\\Training_data_gval', 
    x_col = 'filename',
    y_col = 'category',
    target_size = IMAGE_SIZE,
    class_mode = 'categorical',
    batch_size = batch_size
)
# Out:
# Found 720 validated image filenames belonging to 3 classes.

# %%
validation_datagen = ImageDataGenerator(rescale=1./255)

validation_generator = validation_datagen.flow_from_dataframe (
    
    validate_df, 
    path + '\\Training_data_gval', 
    x_col ='filename',
    y_col = 'category',
    target_size = IMAGE_SIZE,
    class_mode = 'categorical',
    batch_size = batch_size
)
# Out:
# Found 180 validated image filenames belonging to 3 classes.

# %%
example_df = train_df.sample(n=1).reset_index(drop=True)

example_generator = train_datagen.flow_from_dataframe (
    
    example_df, 
    path + '\\Training_data_gval', 
    x_col = 'filename',
    y_col = 'category',
    target_size = IMAGE_SIZE,
    class_mode = 'categorical'
)
# Out:
# Found 1 validated image filenames belonging to 1 classes.

# %%
print(example_df)

plt.figure(figsize=(12, 12))

for i in range(0, 15):
    
    plt.subplot(5, 3, i+1)
    
    for X_batch, Y_batch in example_generator:
        image = X_batch[0]
        plt.imshow(image)
        break
        
plt.tight_layout()
plt.show()
# Out:
#                   filename         category
# 0  Viral Pneumonia-130.png  Viral Pneumonia

# %%
epochs = 25

history = model.fit_generator (
    
    train_generator, 
    epochs = epochs,
    validation_data = validation_generator,
    validation_steps = total_validate//batch_size,
    steps_per_epoch = total_train//batch_size,
    callbacks = callbacks
)
# Out:
# C:\Users\DEEP\anaconda3\envs\tf\lib\site-packages\keras\engine\training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/25
# 144/144 [==============================] - 27s 175ms/step - loss: 1.0688 - accuracy: 0.6375 - val_loss: 3.1810 - val_accuracy: 0.3500
# Epoch 2/25
# 144/144 [==============================] - 26s 183ms/step - loss: 0.8063 - accuracy: 0.7167 - val_loss: 3.3276 - val_accuracy: 0.3667
# Epoch 3/25
# 144/144 [==============================] - 28s 193ms/step - loss: 0.7290 - accuracy: 0.7611 - val_loss: 2.3078 - val_accuracy: 0.5389
# Epoch 4/25
# 144/144 [==============================] - 27s 188ms/step - loss: 0.6338 - accuracy: 0.7806 - val_loss: 0.5914 - val_accuracy: 0.8167
# Epoch 5/25
# 144/144 [==============================] - 22s 155ms/step - loss: 0.5324 - accuracy: 0.8014 - val_loss: 3.4456 - val_accuracy: 0.5444
# Epoch 6/25
# 144/144 [==============================] - 23s 159ms/step - loss: 0.5791 - accuracy: 0.7861 - val_loss: 0.9342 - val_accuracy: 0.7167
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 7/25
# 144/144 [==============================] - 24s 166ms/step - loss: 0.4419 - accuracy: 0.8444 - val_loss: 0.9688 - val_accuracy: 0.7444
# Epoch 8/25
# 144/144 [==============================] - 23s 161ms/step - loss: 0.4147 - accuracy: 0.8472 - val_loss: 0.4253 - val_accuracy: 0.8722
# Epoch 9/25
# 144/144 [==============================] - 23s 158ms/step - loss: 0.4087 - accuracy: 0.8569 - val_loss: 0.7319 - val_accuracy: 0.8000
# Epoch 10/25
# 144/144 [==============================] - 23s 156ms/step - loss: 0.3598 - accuracy: 0.8722 - val_loss: 0.4827 - val_accuracy: 0.8444
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 11/25
# 144/144 [==============================] - 23s 160ms/step - loss: 0.3602 - accuracy: 0.8639 - val_loss: 0.5663 - val_accuracy: 0.8167
# Epoch 12/25
# 144/144 [==============================] - 22s 155ms/step - loss: 0.3054 - accuracy: 0.8819 - val_loss: 0.3995 - val_accuracy: 0.8778
# Epoch 13/25
# 144/144 [==============================] - 23s 161ms/step - loss: 0.2746 - accuracy: 0.9014 - val_loss: 0.3376 - val_accuracy: 0.9167
# Epoch 14/25
# 144/144 [==============================] - 22s 156ms/step - loss: 0.2617 - accuracy: 0.8986 - val_loss: 0.3527 - val_accuracy: 0.9000
# Epoch 15/25
# 144/144 [==============================] - 23s 161ms/step - loss: 0.2214 - accuracy: 0.9153 - val_loss: 0.3566 - val_accuracy: 0.8833
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 16/25
# 144/144 [==============================] - 22s 156ms/step - loss: 0.2111 - accuracy: 0.9222 - val_loss: 0.3488 - val_accuracy: 0.9056
# Epoch 17/25
# 144/144 [==============================] - 24s 164ms/step - loss: 0.2424 - accuracy: 0.9181 - val_loss: 0.2815 - val_accuracy: 0.9278
# Epoch 18/25
# 144/144 [==============================] - 23s 157ms/step - loss: 0.2258 - accuracy: 0.9236 - val_loss: 0.3137 - val_accuracy: 0.9167
# Epoch 19/25
# 144/144 [==============================] - 23s 158ms/step - loss: 0.1814 - accuracy: 0.9347 - val_loss: 0.3694 - val_accuracy: 0.9167
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 20/25
# 144/144 [==============================] - 23s 161ms/step - loss: 0.2234 - accuracy: 0.9222 - val_loss: 0.3096 - val_accuracy: 0.9278
# Epoch 21/25
# 144/144 [==============================] - 22s 155ms/step - loss: 0.2339 - accuracy: 0.9194 - val_loss: 0.2909 - val_accuracy: 0.9389
# Epoch 22/25
# 144/144 [==============================] - 23s 161ms/step - loss: 0.2052 - accuracy: 0.9208 - val_loss: 0.3335 - val_accuracy: 0.9278
# Epoch 23/25
# 144/144 [==============================] - 23s 160ms/step - loss: 0.2186 - accuracy: 0.9222 - val_loss: 0.3086 - val_accuracy: 0.9278
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 24/25
# 144/144 [==============================] - 23s 162ms/step - loss: 0.1880 - accuracy: 0.9306 - val_loss: 0.2933 - val_accuracy: 0.9389
# Epoch 25/25
# 144/144 [==============================] - 23s 159ms/step - loss: 0.2548 - accuracy: 0.9181 - val_loss: 0.2922 - val_accuracy: 0.9389
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
numEpochs = range(1,  25 + 1)
plt.plot(numEpochs, accuracy, 'g', label='Training Accuracy')
plt.plot(numEpochs, val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
numEpochs = range(1,  25 + 1)
plt.plot(numEpochs, loss, 'g', label='Training Loss')
plt.plot(numEpochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
test_filenames = os.listdir(path + 'Test_data')

test_df = pd.DataFrame({
    'filename': test_filenames
})

nb_samples = test_df.shape[0]
test_df = test_df.sample(frac=1).reset_index(drop=True)
test_df
# Out:
#                     filename
# 0            Normal-1831.png
# 1             COVID-1733.png
# 2            Normal-1853.png
# 3            Normal-1887.png
# 4            Normal-1896.png
# ..                       ...
# 596           COVID-1752.png
# 597  Viral Pneumonia-862.png
# 598          Normal-1927.png
# 599  Viral Pneumonia-801.png
# 600  Viral Pneumonia-803.png
#
# [601 rows x 1 columns]

# %%
test_df
# Out:
#                     filename
# 0            Normal-1831.png
# 1             COVID-1733.png
# 2            Normal-1853.png
# 3            Normal-1887.png
# 4            Normal-1896.png
# ..                       ...
# 596           COVID-1752.png
# 597  Viral Pneumonia-862.png
# 598          Normal-1927.png
# 599  Viral Pneumonia-801.png
# 600  Viral Pneumonia-803.png
#
# [601 rows x 1 columns]

# %%
test_gen = ImageDataGenerator(rescale = 1./255)
test_generator = test_gen.flow_from_dataframe(
    
    test_df, 
    path + '\\Test_data', 
    x_col = 'filename',
    y_col = None,
    class_mode = None,
    target_size = IMAGE_SIZE,
    batch_size = batch_size,
    shuffle = False
)
# Out:
# Found 601 validated image filenames.

# %%
predict = model.predict_generator(test_generator, steps = np.ceil(nb_samples/batch_size))
# Out:
# C:\Users\DEEP\anaconda3\envs\tf\lib\site-packages\keras\engine\training.py:2035: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '

# %%
test_df['category'] = np.argmax(predict, axis=-1)

# %%
label_map = dict((v,k) for k,v in train_generator.class_indices.items())
test_df['category'] = test_df['category'].replace(label_map)
test_df
# Out:
#                     filename         category
# 0            Normal-1831.png           Normal
# 1             COVID-1733.png  Viral Pneumonia
# 2            Normal-1853.png            COVID
# 3            Normal-1887.png            COVID
# 4            Normal-1896.png           Normal
# ..                       ...              ...
# 596           COVID-1752.png            COVID
# 597  Viral Pneumonia-862.png  Viral Pneumonia
# 598          Normal-1927.png            COVID
# 599  Viral Pneumonia-801.png            COVID
# 600  Viral Pneumonia-803.png            COVID
#
# [601 rows x 2 columns]

# %%
test_df['category'] = test_df['category'].replace({'Normal': 0, 'COVID': 1, 'Viral Pneumonia': 2})

# %%
test_df['category'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
sample_test = test_df.head(18)
sample_test.head()

plt.figure(figsize=(12, 24))

for index, row in sample_test.iterrows():
    
    filename = row['filename']
    category = row['category']
    
    img = load_img(path + 'Test_data\\' + filename, target_size=IMAGE_SIZE)
    
    plt.subplot(6, 3, index+1)
    plt.imshow(img)
    plt.xlabel(filename + ' Pred: (' + "{}".format(category) + ')' )
    
plt.tight_layout()
plt.show()

# %%
sample_test = test_df
correctPredictions = 0

correctNormalPred = 0
correctCovidPred = 0
correctPneuPred = 0

totalNormalPred = 0
totalCovidPred = 0
totalPneuPred = 0

for index, row in sample_test.iterrows():
    
    filename = row['filename']
    prediction = row['category']
    
    img = load_img(path + 'Test_data\\' + filename, target_size=IMAGE_SIZE)
    
    if 'Normal' in filename:
        
        if prediction == 0:
            correctPredictions += 1
            correctNormalPred += 1
            
        totalNormalPred += 1
    
    if 'COVID' in filename:
        
        if prediction == 1: 
            correctPredictions += 1
            correctCovidPred += 1
            
        totalCovidPred += 1
    
    if 'Viral Pneumonia' in filename:
        
        if prediction == 2: 
            correctPredictions += 1
            correctPneuPred += 1
            
        totalPneuPred += 1

# %%
print('Model Accuracy:', "{:.2%}".format(correctPredictions / test_df.shape[0]))
print('Correct Predictions:', correctPredictions, 'Total Predictions:', test_df.shape[0])

print('\nNormal Predictions:', correctNormalPred, 'Accuracy', "{:.2%}".format(correctNormalPred /  totalNormalPred))
print('COVID-19 Predictions:', correctCovidPred, 'Accuracy', "{:.2%}".format(correctCovidPred /  totalCovidPred))
print('Viral Pneumonia Predictions:', correctPneuPred, 'Accuracy', "{:.2%}".format(correctPneuPred / totalPneuPred))
# Out:
# Model Accuracy: 73.88%
# Correct Predictions: 444 Total Predictions: 601
#
# Normal Predictions: 95 Accuracy 47.26%
# COVID-19 Predictions: 155 Accuracy 77.50%
# Viral Pneumonia Predictions: 194 Accuracy 97.00%
